# %%
# !cd /home/thinh-do/Workspace/Furniture_Detection/
# !python3 /home/thinh-do/Workspace/Furniture_Detection/train.py --dataset csv --csv_train /home/thinh-do/Workspace/Furniture_Detection/processes_data/train.csv  --csv_classes /home/thinh-do/Workspace/Furniture_Detection/processes_data/classes.csv  --csv_val /home/thinh-do/Workspace/Furniture_Detection/processes_data/val.csv --epochs 30
# Out:
# /home/thinh-do/.local/lib/python3.8/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper
# CUDA available: False
# Num training images: 4225
# Train:
# 	Epoch 1/30:
# 	it:4/4225 | 0m 28s | Classification loss: 1.13524 | Regression loss: 1.07289 | Running loss: 2.20813
# 	it:8/4225 | 0m 28s | Classification loss: 421.99139 | Regression loss: 1.69590 | Running loss: 212.94771
# 	it:12/4225 | 0m 34s | Classification loss: 452.90140 | Regression loss: 2.07721 | Running loss: 293.62467
# 	it:16/4225 | 0m 37s | Classification loss: 2.60123 | Regression loss: 3.08993 | Running loss: 221.64130
# 	it:20/4225 | 0m 39s | Classification loss: 1.59860 | Regression loss: 2.84704 | Running loss: 178.20216
# ...

# %%
# !python3 ../pytorch-retinanet/visualize_single_image.py --class_list ./classes.csv --result_dir /home/thinh-do/Workspace/Furniture_detection/result/visualize_single_image --model_path /home/thinh-do/Workspace/Furniture_detection_use_retinanet/web/retinanet.pt --image_dir /home/thinh-do/Workspace/Furniture_detection/OID/Dataset/test
# Out:
# torch.Size([1, 3, 640, 832]) (768, 1024, 3) 0.7916666666666666
# /home/thinh-do/.local/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Elapsed time: 3.7205545902252197
# tensor([  8.4072, 378.8446, 166.2185, 463.3516]) torch.Size([249])
# torch.Size([1, 3, 640, 640]) (1024, 1024, 3) 0.59375
# Elapsed time: 2.804814100265503
# tensor([179.7210, 229.7722, 341.6093, 438.4501]) torch.Size([28])
# torch.Size([1, 3, 640, 832]) (768, 1024, 3) 0.7916666666666666
# Elapsed time: 3.0139386653900146
# torch.Size([1, 3, 640, 832]) (768, 1024, 3) 0.7916666666666666
# Elapsed time: 3.8666326999664307
# ...

# %%
# !python3 ./pytorch-retinanet/visualize.py --csv_classes ./classes.csv --result_dir /home/thinh-do/Workspace/Furniture_detection/result/visualize --model ./retinanet.pt  --dataset csv --csv_val /home/thinh-do/Workspace/Furniture_detection/val.csv --csv_train /home/thinh-do/Workspace/Furniture_detection/train.csv
# Out:
# /home/thinh-do/.local/lib/python3.8/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper
# CUDA available: False
# /home/thinh-do/.local/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Elapsed time: 3.9198312759399414
# Bed
# Elapsed time: 3.430494546890259
# Couch
# Elapsed time: 2.851454257965088
# Bed
# Elapsed time: 2.4597110748291016
# ...

# %%
# !python3 /home/thinh-do/Workspace/Furniture_detection/pytorch-retinanet/csv_validation.py --model_path /home/thinh-do/Workspace/Furniture_detection/retinanet.pt --csv_annotations_path /home/thinh-do/Workspace/Furniture_detection/test.csv --class_list_path /home/thinh-do/Workspace/Furniture_detection/classes.csv --images_path /home/thinh-do/Workspace/Furniture_detection/OID/Dataset/test
# Out:
# /home/thinh-do/.local/lib/python3.8/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper
# CUDA available: False
# Traceback (most recent call last):
#   File "/home/thinh-do/Workspace/Furniture_detection/pytorch-retinanet/csv_validation.py", line 53, in <module>
#     main()
#   File "/home/thinh-do/Workspace/Furniture_detection/pytorch-retinanet/csv_validation.py", line 41, in main
#     retinanet.load_state_dict(torch.load(parser.model_path,map_location='cpu'))
#   File "/home/thinh-do/.local/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1379, in load_state_dict
#     state_dict = state_dict.copy()
# ...
